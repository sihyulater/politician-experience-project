# %%
import requests
import json
import redis
import pandas as pd
from urllib.parse import urlencode

# %%
# caching
redis_client = redis.Redis(host = 'localhost', port = 6379, db = 0)

# %%
# My api here

# %%
def extract_lat_lng(address, address_type = 'administrative_area_level_2', update = False):
    """
    Takes in an address and return the latitude and longitude of the place and the county, state, and country it belongs
    """
    
    lat, lng, county_p, county, county_lat, county_lng, state, country = None, None, None, None, None, None, None, None
    
    place = fetch_place(address, update) # returns a list of places
    if not place:
        return [address] + [None] * 8
    
    # prioritizing the political category, e.g., Ireland as a country over a natural establishment
    if len(place) > 1:
        political_place = list(filter(lambda p: len(p['types']) > 1 and p['types'][1] == 'political', place))
        if political_place:
            place = political_place[0]
        else:
            place = place[0]
    else:
        place = place[0]
    
    place_type = place['types'][0]
    
    # extracting the latitude and longitude of the place
    location = place['geometry']['location']
    lat = location['lat']
    lng = location['lng']

    # extracting the county, state, and country the place belongs to, if any
    for level in place['address_components']:
        if level['types'][0] == 'administrative_area_level_2':
            county = level['long_name']
        if level['types'][0] == 'administrative_area_level_1':
            state = level['short_name']
        if level['types'][0] == 'country':
            country = level['short_name']
                
    # extracting the latitute and longitute of the county
    if county and place_type == 'administrative_area_level_2':
        county_lat = lat
        county_lng = lng
    elif county:
        county_p = fetch_place(f"{county}, {state}, {country}", update)[0]
        county_lat = county_p['geometry']['location']['lat']
        county_lng = county_p['geometry']['location']['lng']

    return [address, place_type, lat, lng, county, county_lat, county_lng, state, country]

# %%
def fetch_place(address, update:bool = False):
    """
    takes in an address and get the json data of the place. If not found in cache then would 
    call the google map API to fetch data.
    """
    
    cases = ("Richmond, Henrico County, Va", "St. Louis, St. Louis County, Mo", "New York City, New York County, N.Y", "Metropolitan City of Palermo, Sicily, IT")
    fixed = ("Richmond, Va", "St. Louis, Mo", "New York City, N.Y", "Palermo, Sicily, Italy")
    if address in cases:
        for pair in zip(cases, fixed):
            if address in pair[0]:
                address = pair[1]
    
    place_key = f"{address}_place"
    place = redis_client.get(place_key)
    
    if update:
        place = None
    
    if not place:
        print('Could not find place in cache. Retrieving from Google Maps API...')
        endpoint = f"https://maps.googleapis.com/maps/api/geocode/json"
        params = {"address": address, "key": api_key}
        url_params = urlencode(params)
        url = f"{endpoint}?{url_params}"
        r = requests.get(url)
        if r.status_code not in range(200, 299):
            place = {}
        else:
            place = r.json()['results']
        
        redis_client.set(place_key, json.dumps(place))
    
    else:
        print('Found place in cache, serving from redis...')
        place = json.loads(place)
        
    return place

# %%
# example
fetch_place("County Monaghan, Ireland", update=False) # can't find this place
# Out:
# Found place in cache, serving from redis...
# []

# %%
df = pd.read_csv("results/bioguide_birth_places_schools.csv")
df.shape
# Out:
# (12967, 27)

# %%
birthplaces = df["birthplace"]
locations = [None] * len(birthplaces)

for i in range(len(birthplaces)):
    print(i, end=' ')
    birthplace = birthplaces[i]
    if type(birthplace) is not str: # missing value
        pass
    else:
        location = extract_lat_lng(birthplaces[i], update=False)
        locations[i] = location
# Out:
# 0 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 1 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 2 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 3 Found place in cache, serving from redis...
# 4 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 5 6 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 7 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 8 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 9 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 10 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 11 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12 Found place in cache, serving from redis...
# 13 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 14 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 15 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 16 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 17 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 18 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 19 Found place in cache, serving from redis...
# 20 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 21 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 22 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 23 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 24 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 25 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 26 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 27 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 28 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 29 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 30 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 31 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 32 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 33 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 34 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 35 Found place in cache, serving from redis...
# 36 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 37 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 38 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 39 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 40 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 41 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 42 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 43 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 44 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 45 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 46 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 47 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 48 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 49 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 50 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 51 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 52 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 53 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 54 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 55 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 56 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 57 Found place in cache, serving from redis...
# 58 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 59 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 60 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 61 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 62 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 63 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 64 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 65 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 66 Found place in cache, serving from redis...
# 67 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 68 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 69 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 70 71 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 72 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 73 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 74 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 75 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 76 Found place in cache, serving from redis...
# 77 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 78 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 79 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 80 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 81 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 82 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 83 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 84 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 85 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 86 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 87 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 88 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 89 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 90 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 91 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 92 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 93 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 94 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 95 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 96 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 97 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 98 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 99 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 100 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 101 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 102 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 103 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 104 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 105 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 106 Found place in cache, serving from redis...
# 107 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 108 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 109 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 110 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 111 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 112 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 113 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 114 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 115 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 116 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 117 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 118 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 119 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 120 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 121 Found place in cache, serving from redis...
# 122 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 123 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 124 Found place in cache, serving from redis...
# 125 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 126 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 127 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 128 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 129 Found place in cache, serving from redis...
# 130 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 131 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 132 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 133 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 134 Found place in cache, serving from redis...
# 135 136 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 137 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 138 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 139 Found place in cache, serving from redis...
# 140 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 141 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 142 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 143 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 144 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 145 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 146 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 147 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 148 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 149 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 150 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 151 Found place in cache, serving from redis...
# 152 Found place in cache, serving from redis...
# 153 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 154 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 155 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 156 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 157 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 158 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 159 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 160 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 161 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 162 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 163 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 164 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 165 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 166 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 167 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 168 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 169 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 170 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 171 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 172 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 173 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 174 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 175 Found place in cache, serving from redis...
# 176 Found place in cache, serving from redis...
# 177 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 178 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 179 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 180 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 181 Found place in cache, serving from redis...
# 182 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 183 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 184 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 185 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 186 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 187 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 188 Found place in cache, serving from redis...
# 189 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 190 Found place in cache, serving from redis...
# 191 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 192 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 193 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 194 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 195 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 196 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 197 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 198 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 199 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 200 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 201 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 202 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 203 Found place in cache, serving from redis...
# 204 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 205 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 206 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 207 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 208 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 209 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 210 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 211 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 212 Found place in cache, serving from redis...
# 213 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 214 Found place in cache, serving from redis...
# 215 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 216 Found place in cache, serving from redis...
# 217 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 218 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 219 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 220 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 221 Found place in cache, serving from redis...
# 222 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 223 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 224 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 225 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 226 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 227 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 228 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 229 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 230 231 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 232 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 233 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 234 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 235 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 236 Found place in cache, serving from redis...
# 237 Found place in cache, serving from redis...
# 238 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 239 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 240 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 241 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 242 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 243 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 244 Found place in cache, serving from redis...
# 245 Found place in cache, serving from redis...
# 246 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 247 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 248 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 249 Found place in cache, serving from redis...
# 250 Found place in cache, serving from redis...
# 251 Found place in cache, serving from redis...
# 252 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 253 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 254 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 255 Found place in cache, serving from redis...
# 256 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 257 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 258 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 259 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 260 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 261 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 262 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 263 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 264 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 265 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 266 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 267 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 268 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 269 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 270 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 271 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 272 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 273 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 274 Found place in cache, serving from redis...
# 275 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 276 Found place in cache, serving from redis...
# 277 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 278 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 279 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 280 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 281 Found place in cache, serving from redis...
# 282 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 283 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 284 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 285 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 286 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 287 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 288 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 289 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 290 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 291 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 292 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 293 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 294 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 295 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 296 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 297 Found place in cache, serving from redis...
# 298 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 299 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 300 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 301 Found place in cache, serving from redis...
# 302 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 303 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 304 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 305 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 306 Found place in cache, serving from redis...
# 307 Found place in cache, serving from redis...
# 308 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 309 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 310 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 311 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 312 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 313 Found place in cache, serving from redis...
# 314 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 315 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 316 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 317 Found place in cache, serving from redis...
# 318 Found place in cache, serving from redis...
# 319 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 320 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 321 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 322 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 323 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 324 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 325 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 326 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 327 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 328 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 329 Found place in cache, serving from redis...
# 330 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 331 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 332 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 333 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 334 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 335 Found place in cache, serving from redis...
# 336 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 337 Found place in cache, serving from redis...
# 338 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 339 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 340 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 341 Found place in cache, serving from redis...
# 342 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 343 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 344 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 345 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 346 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 347 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 348 Found place in cache, serving from redis...
# 349 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 350 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 351 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 352 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 353 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 354 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 355 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 356 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 357 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 358 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 359 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 360 Found place in cache, serving from redis...
# 361 Found place in cache, serving from redis...
# 362 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 363 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 364 Found place in cache, serving from redis...
# 365 Found place in cache, serving from redis...
# 366 Found place in cache, serving from redis...
# 367 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 368 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 369 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 370 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 371 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 372 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 373 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 374 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 375 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 376 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 377 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 378 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 379 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 380 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 381 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 382 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 383 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 384 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 385 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 386 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 387 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 388 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 389 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 390 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 391 Found place in cache, serving from redis...
# 392 Found place in cache, serving from redis...
# 393 Found place in cache, serving from redis...
# 394 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 395 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 396 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 397 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 398 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 399 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 400 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 401 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 402 Found place in cache, serving from redis...
# 403 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 404 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 405 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 406 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 407 Found place in cache, serving from redis...
# 408 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 409 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 410 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 411 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 412 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 413 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 414 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 415 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 416 Found place in cache, serving from redis...
# 417 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 418 Found place in cache, serving from redis...
# 419 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 420 Found place in cache, serving from redis...
# 421 Found place in cache, serving from redis...
# 422 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 423 Found place in cache, serving from redis...
# 424 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 425 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 426 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 427 Found place in cache, serving from redis...
# 428 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 429 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 430 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 431 Found place in cache, serving from redis...
# 432 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 433 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 434 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 435 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 436 Found place in cache, serving from redis...
# 437 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 438 Found place in cache, serving from redis...
# 439 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 440 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 441 Found place in cache, serving from redis...
# 442 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 443 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 444 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 445 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 446 Found place in cache, serving from redis...
# 447 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 448 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 449 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 450 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 451 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 452 Found place in cache, serving from redis...
# 453 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 454 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 455 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 456 Found place in cache, serving from redis...
# 457 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 458 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 459 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 460 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 461 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 462 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 463 Found place in cache, serving from redis...
# 464 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 465 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 466 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 467 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 468 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 469 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 470 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 471 Found place in cache, serving from redis...
# 472 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 473 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 474 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 475 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 476 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 477 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 478 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 479 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 480 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 481 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 482 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 483 Found place in cache, serving from redis...
# 484 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 485 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 486 Found place in cache, serving from redis...
# 487 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 488 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 489 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 490 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 491 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 492 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 493 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 494 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 495 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 496 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 497 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 498 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 499 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 500 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 501 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 502 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 503 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 504 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 505 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 506 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 507 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 508 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 509 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 510 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 511 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 512 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 513 Found place in cache, serving from redis...
# 514 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 515 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 516 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 517 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 518 Found place in cache, serving from redis...
# 519 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 520 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 521 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 522 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 523 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 524 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 525 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 526 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 527 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 528 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 529 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 530 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 531 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 532 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 533 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 534 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 535 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 536 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 537 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 538 Found place in cache, serving from redis...
# 539 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 540 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 541 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 542 Found place in cache, serving from redis...
# 543 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 544 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 545 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 546 Found place in cache, serving from redis...
# 547 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 548 Found place in cache, serving from redis...
# 549 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 550 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 551 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 552 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 553 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 554 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 555 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 556 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 557 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 558 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 559 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 560 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 561 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 562 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 563 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 564 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# ...
# Found place in cache, serving from redis...
# 12785 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12786 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12787 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12788 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12789 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12790 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12791 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12792 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12793 Found place in cache, serving from redis...
# 12794 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12795 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12796 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12797 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12798 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12799 Found place in cache, serving from redis...
# 12800 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12801 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12802 Found place in cache, serving from redis...
# 12803 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12804 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12805 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12806 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12807 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12808 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12809 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12810 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12811 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12812 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12813 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12814 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12815 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12816 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12817 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12818 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12819 Found place in cache, serving from redis...
# 12820 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12821 Found place in cache, serving from redis...
# 12822 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12823 Found place in cache, serving from redis...
# 12824 Found place in cache, serving from redis...
# 12825 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12826 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12827 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12828 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12829 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12830 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12831 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12832 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12833 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12834 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12835 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12836 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12837 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12838 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12839 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12840 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12841 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12842 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12843 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12844 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12845 Found place in cache, serving from redis...
# 12846 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12847 Found place in cache, serving from redis...
# 12848 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12849 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12850 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12851 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12852 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12853 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12854 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12855 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12856 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12857 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12858 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12859 Found place in cache, serving from redis...
# 12860 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12861 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12862 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12863 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12864 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12865 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12866 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12867 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12868 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12869 Found place in cache, serving from redis...
# 12870 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12871 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12872 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12873 12874 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12875 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12876 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12877 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12878 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12879 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12880 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12881 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12882 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12883 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12884 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12885 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12886 Found place in cache, serving from redis...
# 12887 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12888 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12889 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12890 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12891 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12892 Found place in cache, serving from redis...
# 12893 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12894 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12895 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12896 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12897 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12898 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12899 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12900 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12901 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12902 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12903 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12904 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12905 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12906 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12907 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12908 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12909 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12910 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12911 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12912 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12913 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12914 Found place in cache, serving from redis...
# 12915 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12916 Found place in cache, serving from redis...
# 12917 12918 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12919 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12920 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12921 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12922 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12923 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12924 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12925 Found place in cache, serving from redis...
# 12926 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12927 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12928 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12929 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12930 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12931 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12932 Found place in cache, serving from redis...
# 12933 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12934 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12935 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12936 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12937 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12938 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12939 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12940 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12941 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12942 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12943 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12944 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12945 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12946 12947 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12948 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12949 Found place in cache, serving from redis...
# 12950 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12951 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12952 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12953 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12954 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12955 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12956 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12957 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12958 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12959 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12960 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12961 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12962 Found place in cache, serving from redis...
# 12963 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12964 Found place in cache, serving from redis...
# Found place in cache, serving from redis...
# 12965 Found place in cache, serving from redis...
# 12966 Found place in cache, serving from redis...

# %%
# number of locality as initial input unit
locality_num = 0
for location in locations:
    try:
        if location[1] == 'locality':
            locality_num += 1
    except TypeError:
        pass
locality_num
# Out:
# 10182

# %%
for i in range(len(locations)):
    if locations[i] is None:
        locations[i] = [None] * 9
df_locations = pd.DataFrame(locations, columns = ["address", "place_type", "lat", "lng", "county", "county_lat", "county_lng", "state", "country"])
df_locations
# Out:
#                                  address                   place_type  \
# 0      Fairfield, Jefferson County, Iowa                     locality
# 1              Selma, Dallas County, Ala                     locality
# 2            Omaha, Douglas County, Nebr                     locality
# 3                        Todd County, Ky  administrative_area_level_2
# 4          Johnstown, Dauphin County, Pa                     locality
# ...                                  ...                          ...
# 12962               Albemarle County, Va  administrative_area_level_2
# 12963                   New London, Conn                     locality
# 12964                      Brooklyn, N.Y                    political
# 12965                Columbia County, Ga  administrative_area_level_2
# 12966      Trenton, Phillips County, Ark  administrative_area_level_2
#
#              lat        lng             county  county_lat  county_lng state  \
# 0      41.007611 -91.963691   Jefferson County   41.023636  -91.909924    IA
# 1      32.407359 -87.021101      Dallas County   32.233214  -87.142289    AL
# 2      41.256537 -95.934503     Douglas County   41.314812  -96.195132    NE
# 3      36.833864 -87.142289        Todd County   36.833864  -87.142289    KY
# 4      40.326741 -78.921970     Cambria County   40.489423  -78.747621    PA
# ...          ...        ...                ...         ...         ...   ...
# 12962  38.056709 -78.611500   Albemarle County   38.056709  -78.611500    VA
# 12963  41.355654 -72.099521  New London County   41.518519  -72.046816    CT
# 12964  40.678178 -73.944158       Kings County   40.652876  -73.959494    NY
# 12965  33.509851 -82.258330    Columbia County   33.509851  -82.258330    GA
# 12966  34.461121 -90.867513    Phillips County   34.461121  -90.867513    AR
#
#       country
# 0          US
# 1          US
# 2          US
# 3          US
# 4          US
# ...       ...
# 12962      US
# 12963      US
# 12964      US
# 12965      US
# 12966      US
#
# [12967 rows x 9 columns]

# %%
df.loc[df_locations['lat'].isnull()]['birthplace'].to_numpy()
# Out:
# array([nan, nan, nan, nan, 'State', 'County Monaghan, Ireland', 'State',
#        nan, nan, nan, nan, 'State', nan, nan, nan, nan, nan, nan,
#        'Manat&iacute', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        'State', 'July', nan, nan, nan, nan, nan, nan, nan, 'State', nan,
#        nan, 'State', nan, nan, nan, nan, 'State', nan, nan, nan, nan,
#        'St. Lukes Parish, S.C', 'State', nan, 'State', nan, nan, nan,
#        'State', nan, nan, nan, nan, nan, nan, nan, nan, nan], dtype=object)

# %%
df_geocoded = pd.concat([df, df_locations], axis=1)
df_geocoded.head()
# Out:
#    Unnamed: 0 usCongressBioId familyName givenName middleName honorificPrefix  \
# 0           0         W000374      White      Hays     Baxter             Mr.
# 1           1         L000226     Lehman   William        NaN             NaN
# 2           2         F000260       Ford    Gerald    Rudolph             Mr.
# 3           3         M000777      Mills     Roger    Quarles             Mr.
# 4           4         W000724      Woods      John        NaN             Mr.
#
#   unaccentedFamilyName unaccentedGivenName unaccentedMiddleName   birthDate  \
# 0                White                Hays               Baxter  1855-09-21
# 1               Lehman             William                  NaN        1913
# 2                 Ford              Gerald              Rudolph  1913-07-14
# 3                Mills               Roger              Quarles  1832-03-30
# 4                Woods                John                  NaN  1794-10-18
#
#    ... public school                            address  \
# 0  ...             0  Fairfield, Jefferson County, Iowa
# 1  ...             0          Selma, Dallas County, Ala
# 2  ...             1        Omaha, Douglas County, Nebr
# 3  ...             0                    Todd County, Ky
# 4  ...             0      Johnstown, Dauphin County, Pa
#
#                     place_type        lat        lng            county  \
# 0                     locality  41.007611 -91.963691  Jefferson County
# 1                     locality  32.407359 -87.021101     Dallas County
# 2                     locality  41.256537 -95.934503    Douglas County
# 3  administrative_area_level_2  36.833864 -87.142289       Todd County
# 4                     locality  40.326741 -78.921970    Cambria County
#
#   county_lat county_lng state country
# 0  41.023636 -91.909924    IA      US
# 1  32.233214 -87.142289    AL      US
# 2  41.314812 -96.195132    NE      US
# 3  36.833864 -87.142289    KY      US
# 4  40.489423 -78.747621    PA      US
#
# [5 rows x 36 columns]

# %%
df_geocoded.to_csv("results/geocoded_birthplaces.csv", index=False)
