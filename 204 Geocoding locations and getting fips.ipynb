# %%
# !pip install -U googlemaps

# %%
# !pip install censusgeocode

# %%
import googlemaps
from datetime import datetime

import numpy as np
import pandas as pd
import json
import redis
import re
import requests
from urllib.parse import urlencode

# %%
key = open('/Users/elainewei/Desktop/google-api.txt').read()

gmaps = googlemaps.Client(key=key)

# %%
# caching
redis_client = redis.Redis(host = 'localhost', port = 6379, db = 0)

# %%
def get_fips(string, update=False):
    print(string)
    if not isinstance(string, str):
        return None, None
    elif re.search(r'\(.*\)', string) and ('University' not in string) and ('College' not in string) and ('School' not in string):
        # string in parentheses are not locations
        error = 'Not a location'
        return None, error
    else:
        location_result = fetch_place(string, update) # might need a try except
        if len(location_result) == 0:
            error = 'No matched places from Google'
            return None, error
        # elif len(location_result) > 1:
        #     error = "More than one matched place from Google"
        #     return None, error
        elif not check_county(location_result):
            error = "No county matched to string from Google"
            return None, error
        else: 
            try: 
                endpoint = 'https://geo.fcc.gov/api/census/block/find'
                lat = location_result[0]['geometry']['location']['lat']
                lng = location_result[0]['geometry']['location']['lng']
                params = {'latitude': str(lat), 'longitude': str(lng), 'censusYear': '2020', 'format': 'json'}
                url_params = urlencode(params)
                r = requests.get(f"{endpoint}?{url_params}")
                return r.json()['County']['FIPS'], None
            except:
                error = "Census geocoder error"
                return None, error
            

def check_county(location_result):
    address_components = location_result[0]['address_components']
    for component in address_components:
        if 'administrative_area_level_2' in component['types']:
            return True
        # Some cities are not subjected to any counties in the place information, e.g., NYC, St. Louis, Richmond
        elif 'locality' in component['types']:
            return True
    return False

# %%
def fetch_place(string, update:bool = False):
    """
    takes in a string and get the json data of the place. If not found in cache then would 
    call the google map API to fetch data.
    """
    
    place_key = string
    place = redis_client.get(string)
    
    if update:
        place = None
    
    if not place:
        print('Could not find place in cache. Retrieving from Google Maps API...')
        place = gmaps.geocode(string)
        redis_client.set(place_key, json.dumps(place))
    
    else:
        print('Found place in cache, serving from redis...')
        place = json.loads(place)
        
    return place

# %%
# # example
# endpoint = 'https://geo.fcc.gov/api/census/block/find'
# lat = '40.6936488'
# lng = '-89.5889864'
# params = {'latitude': lat, 'longitude': lng, 'censusYear': '2020', 'format': 'json'}
# url_params = urlencode(params)
# r = requests.get(f"{endpoint}?{url_params}")
# r.json()['County']['FIPS']
# Out:
# '17143'

# %%
df = pd.read_csv('results/timeline_gpt4_new_prompt_full.csv')

# %%
df
# Out:
#            id start_1  end_1                         location_1  start_2  \
# 0     C001059    1952   1970      Fresno, Fresno County, Calif.     1970
# 1     S001158    1953   1971     Alamosa, Alamosa County, Colo.     1971
# 2     M001155    1967   1985       Fort Myers, Lee County, Fla.     1985
# 3     W000797    1966   1980  Forest Hills, Queens County, N.Y.     1980
# 4     P000591    1954   1972      Lansing, Ingham County, Mich.     1972
# ...       ...     ...    ...                                ...      ...
# 1305  B001319    1982   1996                   Enterprise, Ala.     1996
# 1306  F000479    1969   1983                     Reading, Penn.     1983
# 1307  R000618    1964   1980               Nebraska City, Nebr.     1980
# 1308  S001227    1975   1989                     Bridgeton, Mo.     1989
# 1309  V000137    1984   1999                   Middletown, Ohio     1999
#
#      end_2            location_2  start_3   end_3  \
# 0     1974        Fresno, Calif.   1978.0  1994.0
# 1     1973  (United States Army)   1973.0  1976.0
# 2     1993     Gainesville, Fla.   2000.0  2003.0
# 3     1984       Dix Hills, N.Y.   1984.0  1988.0
# 4     1976       Dearborn, Mich.   1976.0  1979.0
# ...    ...                   ...      ...     ...
# 1305  2000      Enterprise, Ala.   2000.0  2004.0
# 1306  1987           York, Penn.   1987.0  1991.0
# 1307  1982          Omaha, Nebr.   1982.0  1986.0
# 1308  1993        St. Louis, Mo.   1993.0  1997.0
# 1309  2003      Middletown, Ohio   2003.0  2007.0
#
#                                     location_3  ... location_11 start_12  \
# 0                  (California state assembly)  ...         NaN      NaN
# 1                         (United States Army)  ...         NaN      NaN
# 2     (Florida state house of representatives)  ...         NaN      NaN
# 3                            Gainesville, Fla.  ...         NaN      NaN
# 4                             Ann Arbor, Mich.  ...         NaN      NaN
# ...                                        ...  ...         ...      ...
# 1305                     University of Alabama  ...         NaN      NaN
# 1306                            Reading, Penn.  ...         NaN      NaN
# 1307                             Chicago, Ill.  ...         NaN      NaN
# 1308                           Kirksville, Mo.  ...         NaN      NaN
# 1309              (United States Marine Corps)  ...         NaN      NaN
#
#      end_12  location_12 start_13 end_13 location_13 start_14 end_14  \
# 0       NaN          NaN      NaN    NaN         NaN      NaN    NaN
# 1       NaN          NaN      NaN    NaN         NaN      NaN    NaN
# 2       NaN          NaN      NaN    NaN         NaN      NaN    NaN
# 3       NaN          NaN      NaN    NaN         NaN      NaN    NaN
# 4       NaN          NaN      NaN    NaN         NaN      NaN    NaN
# ...     ...          ...      ...    ...         ...      ...    ...
# 1305    NaN          NaN      NaN    NaN         NaN      NaN    NaN
# 1306    NaN          NaN      NaN    NaN         NaN      NaN    NaN
# 1307    NaN          NaN      NaN    NaN         NaN      NaN    NaN
# 1308    NaN          NaN      NaN    NaN         NaN      NaN    NaN
# 1309    NaN          NaN      NaN    NaN         NaN      NaN    NaN
#
#      location_14
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1305         NaN
# 1306         NaN
# 1307         NaN
# 1308         NaN
# 1309         NaN
#
# [1310 rows x 43 columns]

# %%
i = 1

while f'location_{i}' in df.columns:
    df["fips" + str(i)], df["error" + str(i)] = zip(*df["location_" + str(i)].map(get_fips))
    df.to_csv('results/gpt4_new_prompt_full_timeline_and_fips.csv', index=False)
    i += 1

print("Finished: ")
display(df)
# Out:
# Fresno, Fresno County, Calif.
# Found place in cache, serving from redis...
# Alamosa, Alamosa County, Colo.
# Found place in cache, serving from redis...
# Fort Myers, Lee County, Fla.
# Found place in cache, serving from redis...
# Forest Hills, Queens County, N.Y.
# Found place in cache, serving from redis...
# Lansing, Ingham County, Mich.
# Found place in cache, serving from redis...
# Atlanta, Fulton County, Ga.
# Found place in cache, serving from redis...
# Athens, Clarke County, Ga.
# Found place in cache, serving from redis...
# Chicago, Cook County, Ill.
# Found place in cache, serving from redis...
# Chicago, Cook County, Ill.
# Found place in cache, serving from redis...
# New Albany, Floyd County, Ind.
# Found place in cache, serving from redis...
# Montreal, Quebec, Canada
# Found place in cache, serving from redis...
# Baton Rouge, East Baton Rouge Parish, La.
# Found place in cache, serving from redis...
# Napoleonville, Assumption Parish, La.
# Found place in cache, serving from redis...
# New Orleans, Orleans Parish, La.
# Found place in cache, serving from redis...
# Battle Creek, Calhoun County, Mich.
# Found place in cache, serving from redis...
# Columbia, Boone County, Mo.
# Found place in cache, serving from redis...
# Wichita Falls, Tex.
# Found place in cache, serving from redis...
# Baton Rouge, East Baton Rouge Parish, La.
# Found place in cache, serving from redis...
# Buffalo, Erie County, N.Y.
# Found place in cache, serving from redis...
# Bath, Steuben County, N.Y.
# Found place in cache, serving from redis...
# New York, New York County, N.Y.
# Found place in cache, serving from redis...
# Charlotte, Mecklenburg County, N.C.
# Found place in cache, serving from redis...
# Shawnee, Pottawatomie County, Okla.
# Found place in cache, serving from redis...
# Philadelphia, Philadelphia County, Pa.
# Found place in cache, serving from redis...
# Queens, Queens County, N.Y.
# Found place in cache, serving from redis...
# Allentown, Lehigh County, Pa.
# Found place in cache, serving from redis...
# Pittsburg, Camp County, Tex.
# Found place in cache, serving from redis...
# Temple, Bell County, Tex.
# Found place in cache, serving from redis...
# New Orleans, Jefferson Parish, La.
# Found place in cache, serving from redis...
# Dallas, Dallas County, Tex.
# Found place in cache, serving from redis...
# Borger, Hutchinson County, Tex.
# Found place in cache, serving from redis...
# Bonham, Fannin County, Tex.
# Found place in cache, serving from redis...
# Laredo, Webb County, Tex.
# Found place in cache, serving from redis...
# Elyria, Lorain County, Ohio
# Found place in cache, serving from redis...
# Salem, Marion County, Oreg.
# Found place in cache, serving from redis...
# Detroit Lakes, Becker County, Minn.
# Found place in cache, serving from redis...
# Racine, Racine County, Wis.
# Found place in cache, serving from redis...
# Poston, La Paz County, Ariz.
# Found place in cache, serving from redis...
# Los Angeles, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Ohio
# Found place in cache, serving from redis...
# Floresville, Wilson County, Tex.
# Found place in cache, serving from redis...
# Bejucal, Cuba
# Found place in cache, serving from redis...
# Bremerton, Kitsap County, Wash.
# Found place in cache, serving from redis...
# Flint, Genesee County, Mich.
# Found place in cache, serving from redis...
# Davenport, Scott County, Iowa
# Found place in cache, serving from redis...
# Malden, Middlesex County, Mass.
# Found place in cache, serving from redis...
# Beckley, Raleigh County, W.Va.
# Found place in cache, serving from redis...
# Lexington, Lafayette County, Mo.
# Found place in cache, serving from redis...
# Quitman, Jackson Parish, La.
# Found place in cache, serving from redis...
# Seattle, King County, Wash.
# Found place in cache, serving from redis...
# Long Beach, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Crosby, Divide County, N.D.
# Found place in cache, serving from redis...
# Chicago, Cook County, Ill.
# Found place in cache, serving from redis...
# Wallace, Shoshone County, Idaho
# Found place in cache, serving from redis...
# Marinette, Marinette County, Wis.
# Found place in cache, serving from redis...
# Savannah, Chatham County, Ga.
# Found place in cache, serving from redis...
# Sumter, Sumter County, S.C.
# Found place in cache, serving from redis...
# San Antonio, Bexar County, Tex.
# Found place in cache, serving from redis...
# Houston, Harris County, Tex.
# Found place in cache, serving from redis...
# Waco, McLennan County, Tex.
# Found place in cache, serving from redis...
# Washington, D.C.
# Found place in cache, serving from redis...
# Holyoke, Hampden County, Mass.
# Found place in cache, serving from redis...
# Watertown, Jefferson County, N.Y.
# Found place in cache, serving from redis...
# Huntsville, Madison County, Ala.
# Found place in cache, serving from redis...
# Claypool, Gila County, Ariz.
# Found place in cache, serving from redis...
# Glendale, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# St. Louis, Mo.
# Found place in cache, serving from redis...
# Los Angeles, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# New Haven, New Haven County, Conn.
# Found place in cache, serving from redis...
# Des Moines, Polk County, Iowa
# Found place in cache, serving from redis...
# Lake Providence, East Carroll Parish, La.
# Found place in cache, serving from redis...
# Rahway, Union County, N.J.
# Found place in cache, serving from redis...
# Honesdale, Wayne County, Pa.
# Found place in cache, serving from redis...
# Midland, Midland County, Mich.
# Found place in cache, serving from redis...
# Jamestown, Stutsman County, N.D.
# Found place in cache, serving from redis...
# Fargo, Cass County, N.D.
# Found place in cache, serving from redis...
# Camden, Camden County, N.J.
# Found place in cache, serving from redis...
# Mayaguez, P.R.
# Found place in cache, serving from redis...
# Brevard, Transylvania County, N.C.
# Found place in cache, serving from redis...
# Cincinnati, Hamilton County, Ohio
# Found place in cache, serving from redis...
# Cincinnati, Hamilton County, Ohio
# Found place in cache, serving from redis...
# San Antonio, Bexar County, Tex.
# Found place in cache, serving from redis...
# Corpus Christi, Nueces County, Tex.
# Found place in cache, serving from redis...
# Detroit, Wayne County, Mich.
# Found place in cache, serving from redis...
# Brooklyn, Kings County, N.Y.
# Found place in cache, serving from redis...
# Kansas City, Jackson County, Mo.
# Found place in cache, serving from redis...
# Buffalo, Erie County, N.Y.
# Found place in cache, serving from redis...
# Bayonne, Hudson County, N.J.
# Found place in cache, serving from redis...
# Riverside, Riverside County, Calif.
# Found place in cache, serving from redis...
# Budapest, Hungary
# Found place in cache, serving from redis...
# Barrier, Wayne County, Ky.
# Found place in cache, serving from redis...
# Miami, Dade County, Fla.
# Found place in cache, serving from redis...
# Rahway, Union County, N.J.
# Found place in cache, serving from redis...
# Philadelphia, Philadelphia County, Pa.
# Found place in cache, serving from redis...
# New York City, N.Y.
# Found place in cache, serving from redis...
# Findlay, Hancock County, Ohio
# Found place in cache, serving from redis...
# Colorado Springs, El Paso County, Colo.
# Found place in cache, serving from redis...
# Fate, Rockwall County, Tex.
# Found place in cache, serving from redis...
# Dothan, Houston County, Ala.
# Found place in cache, serving from redis...
# Birmingham, Jefferson County, Ala.
# Found place in cache, serving from redis...
# Seattle, King County, Wash.
# Found place in cache, serving from redis...
# Tracy, San Joaquin County, Calif.
# Found place in cache, serving from redis...
# New Britain, Hartford County, Conn.
# Found place in cache, serving from redis...
# San Francisco, San Francisco County, Calif.
# Found place in cache, serving from redis...
# Los Angeles, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Sacramento, Sacramento County, Calif.
# Found place in cache, serving from redis...
# Boyle Heights, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# New York, N.Y.
# Found place in cache, serving from redis...
# Los Angeles, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Corona, Riverside County, Calif.
# Found place in cache, serving from redis...
# Pittsburgh, Allegheny County, Pa.
# Found place in cache, serving from redis...
# Wilmington, New Castle County, Del.
# Found place in cache, serving from redis...
# Jacksonville, St. John County, Fla.
# Found place in cache, serving from redis...
# Binghamton, Broome County, N.Y.
# Found place in cache, serving from redis...
# Brooklyn, Kings County, N.Y.
# Found place in cache, serving from redis...
# Havana, Cuba
# Found place in cache, serving from redis...
# Altamonte Springs, Seminole County, Fla.
# Found place in cache, serving from redis...
# Bryan, Brazos County, Tex.
# Found place in cache, serving from redis...
# Mobile, Mobile County, Ala.
# Found place in cache, serving from redis...
# Los Angeles, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Tarpon Springs, Pinellas County, Fla.
# Found place in cache, serving from redis...
# Utica, Oneida County, N.Y.
# Found place in cache, serving from redis...
# Atlanta, Fulton County, Ga.
# Found place in cache, serving from redis...
# Deer River, Itasca County, Minn.
# Found place in cache, serving from redis...
# Washington County, Va.
# Found place in cache, serving from redis...
# Albany, Dougherty County, Ga.
# Found place in cache, serving from redis...
# Chicago, Cook County, Ill.
# Found place in cache, serving from redis...
# Rockford, Winnebago County, Ill.
# Found place in cache, serving from redis...
# Indianapolis, Marion County, Ind.
# Found place in cache, serving from redis...
# Rensselaer, Jasper County, Ind.
# Found place in cache, serving from redis...
# McKell, Greenup County, Ky.
# Found place in cache, serving from redis...
# Nashville, Davidson County, Tenn.
# Found place in cache, serving from redis...
# Philadelphia, Montgomery County, Pa.
# Found place in cache, serving from redis...
# Moreland, Jefferson County, Ky.
# Found place in cache, serving from redis...
# Lowell, Middlesex County, Mass.
# Found place in cache, serving from redis...
# Rock Island, Rock Island County, Ill.
# Found place in cache, serving from redis...
# Milwaukee, Milwaukee County, Wis.
# Found place in cache, serving from redis...
# Groningen, Netherlands
# Found place in cache, serving from redis...
# Pipestone, Pipestone County, Minn.
# Found place in cache, serving from redis...
# Chicago, Cook County, Ill.
# Found place in cache, serving from redis...
# Toledo, Lucas County, Ohio
# Found place in cache, serving from redis...
# Mattoon, Coles County, Ill.
# Found place in cache, serving from redis...
# Bolton, Hinds County, Miss.
# Found place in cache, serving from redis...
# Detroit, Wayne County, Mich.
# Found place in cache, serving from redis...
# New York, N.Y.
# Found place in cache, serving from redis...
# New York, New York County, N.Y.
# Found place in cache, serving from redis...
# Brooklyn, Kings County, New York
# Found place in cache, serving from redis...
# Yabucoa, P.R.
# Found place in cache, serving from redis...
# Greensboro, Guilford County, N.C.
# Found place in cache, serving from redis...
# New York, N.Y.
# Found place in cache, serving from redis...
# Steele Creek, Mecklenburg County, N.C.
# Found place in cache, serving from redis...
# Valley City, Barnes County, N.Dak.
# Found place in cache, serving from redis...
# Robstown, Nueces County, Tex.
# Found place in cache, serving from redis...
# Collierville, Shelby County, Tenn.
# Found place in cache, serving from redis...
# Cincinnati, Hamilton County, Ohio
# Found place in cache, serving from redis...
# Mansfield, Richland County, Ohio
# Found place in cache, serving from redis...
# Warren, Trumbull County, Ohio
# Found place in cache, serving from redis...
# Fort Worth, Tarrant County, Tex.
# Found place in cache, serving from redis...
# Cheyenne, Roger Mills County, Okla.
# Found place in cache, serving from redis...
# St. Clair, Schuylkill County, Pa.
# Found place in cache, serving from redis...
# York, S.C.
# Found place in cache, serving from redis...
# Chadbourn, Columbus County, N.C.
# Found place in cache, serving from redis...
# New York, New York County, N.Y.
# Found place in cache, serving from redis...
# Fairmont, Marion County, W.Va.
# Found place in cache, serving from redis...
# Waco, McLennan County, Tex.
# Found place in cache, serving from redis...
# Greensboro, Guilford County, N.C.
# Found place in cache, serving from redis...
# Laredo, Webb County, Tex.
# Found place in cache, serving from redis...
# Harmarville, Allegheny County, Pa.
# Found place in cache, serving from redis...
# Murfreesboro, Rutherford County, Tenn.
# Found place in cache, serving from redis...
# Nanticoke, Luzerne County, Pa.
# Found place in cache, serving from redis...
# Evanston, Cook County, Ill.
# Found place in cache, serving from redis...
# Nicholson, Wyoming County, Pa.
# Found place in cache, serving from redis...
# Gary, Lake County, Ind.
# Found place in cache, serving from redis...
# Phoenix, Pinal County, Ariz.
# Found place in cache, serving from redis...
# Highpoint, Guilford County, N.C.
# Found place in cache, serving from redis...
# San Mateo, San Mateo County, Calif.
# Found place in cache, serving from redis...
# Mariposa, Mariposa County, Calif.
# Found place in cache, serving from redis...
# Coronado, Calif.
# Found place in cache, serving from redis...
# Amityville, Suffolk County, N.Y.
# Found place in cache, serving from redis...
# Newton, Middlesex County, Mass.
# Found place in cache, serving from redis...
# Valdosta, Lowndes County, Ga.
# Found place in cache, serving from redis...
# Streator, La Salle County, Ill.
# Found place in cache, serving from redis...
# Peoria, Peoria County, Ill.
# Found place in cache, serving from redis...
# Fort Wayne, Allen County, Ind.
# Found place in cache, serving from redis...
# Evansville, Vanderburgh County, Ind.
# Found place in cache, serving from redis...
# Hampton, Franklin County, Iowa
# Found place in cache, serving from redis...
# Vermillion, Clay County, S.Dak.
# Found place in cache, serving from redis...
# Hopkinsville, Christian County, Ky.
# Found place in cache, serving from redis...
# Cedar Falls, Black Hawk County, Iowa
# Found place in cache, serving from redis...
# Pontotoc, Pontotoc County, Miss.
# Found place in cache, serving from redis...
# Boston, Suffolk County, Mass.
# Found place in cache, serving from redis...
# Bridgeton, Cumberland County, N.J.
# Found place in cache, serving from redis...
# New York, N.Y.
# Found place in cache, serving from redis...
# Lima, Allen County, Ohio
# Found place in cache, serving from redis...
# Farmville, Pitt County, N.C.
# Found place in cache, serving from redis...
# Tiffin, Seneca County, Ohio
# Found place in cache, serving from redis...
# Cincinnati, Hamilton County, Ohio
# Found place in cache, serving from redis...
# Wheeling, Ohio County, W.Va.
# Found place in cache, serving from redis...
# Cleveland, Cuyahoga County, Ohio
# Found place in cache, serving from redis...
# Philadelphia, Philadelphia County, Pa.
# Found place in cache, serving from redis...
# Swissvale, Allegheny County, Pa.
# Found place in cache, serving from redis...
# Erie, Erie County, Pa.
# Found place in cache, serving from redis...
# Brighton, Middlesex County, Mass.
# Found place in cache, serving from redis...
# Fort Benning, Chattahoochee County, Ga.
# Found place in cache, serving from redis...
# Austin, Travis County, Tex.
# Found place in cache, serving from redis...
# Clarendon, Donley County, Tex.
# Found place in cache, serving from redis...
# Queens, Queens County, N.Y.
# Found place in cache, serving from redis...
# Minot, Ward County, N.Dak.
# Found place in cache, serving from redis...
# Spokane, Spokane County, Wash.
# Found place in cache, serving from redis...
# Buffalo, Erie County, N.Y.
# Found place in cache, serving from redis...
# Salinas, San Benito, Calif.
# Found place in cache, serving from redis...
# Greenville, Pickens County, S.C.
# Found place in cache, serving from redis...
# Birmingham, Jefferson County, Ala.
# Found place in cache, serving from redis...
# Baltimore, Md.
# Found place in cache, serving from redis...
# Portland, Multnomah County, Oreg.
# Found place in cache, serving from redis...
# Haleyville, Winston County, Ala.
# Found place in cache, serving from redis...
# Stuttgart, Arkansas County, Ark.
# Found place in cache, serving from redis...
# Medford, Jackson County, Oreg.
# Found place in cache, serving from redis...
# Newark, Essex County, N.J.
# Found place in cache, serving from redis...
# Los Angeles, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Lynwood, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Tachikawa, Tokyo, Japan
# Found place in cache, serving from redis...
# Millen, Jenkins County, Ga.
# Found place in cache, serving from redis...
# Monticello, Fla.
# Found place in cache, serving from redis...
# Tampa, Hillsborough County, Fla.
# Found place in cache, serving from redis...
# Queens, Queens County, N.Y.
# Found place in cache, serving from redis...
# Parkdale, Ashley County, Ark.
# Found place in cache, serving from redis...
# Collinsville, Madison County, Ill.
# Found place in cache, serving from redis...
# Louisville, Jefferson County, Ky.
# Found place in cache, serving from redis...
# Lamoni, Iowa
# Found place in cache, serving from redis...
# Great Bend, Barton County, Kans.
# Found place in cache, serving from redis...
# Wichita, Sedgewick County, Kans.
# Found place in cache, serving from redis...
# Louisville, Jefferson County, Ky.
# Found place in cache, serving from redis...
# Portland, Cumberland County, Maine
# Found place in cache, serving from redis...
# Worcester, Worcester County, Mass.
# Found place in cache, serving from redis...
# Salem, Essex County, Mass.
# Found place in cache, serving from redis...
# Quincy, Norfolk County, Mass.
# Found place in cache, serving from redis...
# Detroit, Wayne County, Mich.
# Found place in cache, serving from redis...
# Laurel, Jones County, Miss.
# Found place in cache, serving from redis...
# Niangua, Webster County, Mo.
# Found place in cache, serving from redis...
# Bethesda, Montgomery County, Md.
# Found place in cache, serving from redis...
# Sikeston, Scott County, Mo.
# Found place in cache, serving from redis...
# New Orleans, Orleans Parish, La.
# Found place in cache, serving from redis...
# Sparks, Washoe County, Nev.
# Found place in cache, serving from redis...
# Paterson, Passaic County, N.J.
# Found place in cache, serving from redis...
# Englewood, Bergen County, N.J.
# Found place in cache, serving from redis...
# Brooklyn, Kings County, N.Y.
# Found place in cache, serving from redis...
# Sampson County, N.C.
# Found place in cache, serving from redis...
# Lumberton, Robeson County, N.C.
# Found place in cache, serving from redis...
# Lucasville, Scioto County, Ohio
# Found place in cache, serving from redis...
# Cleveland, Cuyahoga County, Ohio
# Found place in cache, serving from redis...
# Baltimore, Md.
# Found place in cache, serving from redis...
# Williston, Williams County, N. Dak.
# Found place in cache, serving from redis...
# Titusville, Crawford County, Pa.
# Found place in cache, serving from redis...
# Lexington, Fayette County, Ky.
# Found place in cache, serving from redis...
# Needham, Norfolk County, Mass.
# Found place in cache, serving from redis...
# Huntington Park, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Ardmore, Carter County, Okla.
# Found place in cache, serving from redis...
# Yuba City, Calif.
# Found place in cache, serving from redis...
# Memphis, Shelby County, Tenn.
# Found place in cache, serving from redis...
# Detroit, Wayne County, Mich.
# Found place in cache, serving from redis...
# Waco, McLennan County, Tex.
# Found place in cache, serving from redis...
# Vermillion, Clay County, S.Dak.
# Found place in cache, serving from redis...
# Aurora, Kane County, Ill.
# Found place in cache, serving from redis...
# Greenville, Hunt County, Tex.
# Found place in cache, serving from redis...
# Edcouch, Hidalgo County, Tex.
# Found place in cache, serving from redis...
# Canutillo, El Paso County, Tex.
# Found place in cache, serving from redis...
# Salt Lake City, Salt Lake County, Utah
# Found place in cache, serving from redis...
# Troy, Pike County, Ala.
# Found place in cache, serving from redis...
# Washington, D.C.
# Found place in cache, serving from redis...
# La Crosse, La Crosse County, Wis.
# Found place in cache, serving from redis...
# Staten Island, Richmond County, N.Y.
# Found place in cache, serving from redis...
# Erwin, Unicoi County, Tenn.
# Found place in cache, serving from redis...
# Ladysmith, Rusk County, Wis.
# Found place in cache, serving from redis...
# Cleveland, Cuyahoga County, Ohio
# Found place in cache, serving from redis...
# East Harlem, New York County, N.Y.
# Found place in cache, serving from redis...
# Philadelphia, Philadelphia County, Pa.
# Found place in cache, serving from redis...
# El Paso, El Paso County, Tex.
# Found place in cache, serving from redis...
# Harlan County, Ky.
# Found place in cache, serving from redis...
# San Antonio, Bexar County, Tex.
# Found place in cache, serving from redis...
# St. Joseph, Berrien County, Mich.
# Found place in cache, serving from redis...
# Marcus Hook, Delaware County, Pa.
# Found place in cache, serving from redis...
# Keene, Cheshire County, N.H.
# Found place in cache, serving from redis...
# Stamford, Fairfield County, Conn.
# Found place in cache, serving from redis...
# Baltimore, Md.
# Found place in cache, serving from redis...
# Shreveport, Caddo Parish, La.
# Found place in cache, serving from redis...
# East St. Louis, St. Clair County, Ill.
# Found place in cache, serving from redis...
# Long Branch, Monmouth County, N.J.
# Found place in cache, serving from redis...
# Lebanon, Wilson County, Tenn.
# Found place in cache, serving from redis...
# St. Helena, Napa County, Calif.
# Found place in cache, serving from redis...
# Brownsville, Cameron County, Tex.
# Found place in cache, serving from redis...
# Huntsville, Madison County, Ark.
# Found place in cache, serving from redis...
# Tucson, Pima County, Ariz.
# Found place in cache, serving from redis...
# Denver, Denver County, Colo.
# Found place in cache, serving from redis...
# Hartford, Hartford County, Conn.
# Found place in cache, serving from redis...
# Burley, Cassia County, Idaho
# Found place in cache, serving from redis...
# Chicago, Cook County, Ill.
# Found place in cache, serving from redis...
# Chicago, Cook County, Ill.
# Found place in cache, serving from redis...
# Anthony, Harper County, Kans.
# Found place in cache, serving from redis...
# Somerville, Middlesex County, Mass.
# Found place in cache, serving from redis...
# Omaha, Douglas County, Nebr.
# Found place in cache, serving from redis...
# New York, N.Y.
# Found place in cache, serving from redis...
# Weston, Lewis County, W. Va.
# Found place in cache, serving from redis...
# Tucson, Pima County, Ariz.
# Found place in cache, serving from redis...
# New York, New York County, N.Y.
# Found place in cache, serving from redis...
# New York City, N.Y.
# Found place in cache, serving from redis...
# Troy, Rensselaer County, N.Y.
# Found place in cache, serving from redis...
# Belfonte, Centre County, Pa.
# Found place in cache, serving from redis...
# Concord, Cabarrus County, N.C.
# Found place in cache, serving from redis...
# Cleveland, Cuyahoga County, Ohio
# Found place in cache, serving from redis...
# Taiwan
# Found place in cache, serving from redis...
# The Dalles, Wasco County, Ore.
# Found place in cache, serving from redis...
# Nicholson, Wyoming County, Pa.
# Found place in cache, serving from redis...
# St. Paul, Ramsey County, Minn.
# Found place in cache, serving from redis...
# Seattle, King County, Wash.
# Found place in cache, serving from redis...
# Bronx County, N.Y.
# Found place in cache, serving from redis...
# Tiffin, Seneca County, Ohio
# Found place in cache, serving from redis...
# Chama, Rio Arriba County, N.Mex.
# Found place in cache, serving from redis...
# Janesville, Rock County, Wis.
# Found place in cache, serving from redis...
# Madison, Dane County, Wis.
# Found place in cache, serving from redis...
# Boston, Suffolk County, Mass.
# Found place in cache, serving from redis...
# Belen, Valencia County, N.Mex.
# Found place in cache, serving from redis...
# San Antonio, Bexar County, Tex.
# Found place in cache, serving from redis...
# Bronx County, N.Y.
# Found place in cache, serving from redis...
# Chicago, Cook County, Ill.
# Found place in cache, serving from redis...
# Troy, Rensselaer County, N.Y.
# Found place in cache, serving from redis...
# Springfield, Hampden County, Mass.
# Found place in cache, serving from redis...
# Newark, Essex County, N.J.
# Found place in cache, serving from redis...
# Coronado, San Diego County, Calif.
# Found place in cache, serving from redis...
# Washington, D.C.
# Found place in cache, serving from redis...
# Halls, Lauderdale County, Tenn.
# Found place in cache, serving from redis...
# Syracuse, Onondaga County, N.Y.
# Found place in cache, serving from redis...
# Havana, Cuba
# Found place in cache, serving from redis...
# New Orleans, Orleans Parish, La.
# Found place in cache, serving from redis...
# Snowflake, Navajo County, Ariz.
# Found place in cache, serving from redis...
# Shreveport, La.
# Found place in cache, serving from redis...
# Texarkana, Miller County, Ark.
# Found place in cache, serving from redis...
# Walnut Grove, Solano County, Calif.
# Found place in cache, serving from redis...
# Framingham, Middlesex County, Mass.
# Found place in cache, serving from redis...
# Los Angeles, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Los Angeles, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Cleveland, Cuyahoga County, Ohio
# Found place in cache, serving from redis...
# Cambridge, Middlesex County, Mass.
# Found place in cache, serving from redis...
# New York, N.Y.
# Found place in cache, serving from redis...
# Pinellas County, Fla.
# Found place in cache, serving from redis...
# Jacksonville, Duval County, Fla.
# Found place in cache, serving from redis...
# Johnson City, Washington County, Tenn.
# Found place in cache, serving from redis...
# Bartow, Polk County, Fla.
# Found place in cache, serving from redis...
# Caldwell, Canyon County, Idaho
# Found place in cache, serving from redis...
# Champaign, Champaign County, Ill.
# Found place in cache, serving from redis...
# Urbana, Champaign County, Ill.
# Found place in cache, serving from redis...
# Columbus, Bartholomew County, Ind.
# Found place in cache, serving from redis...
# Boston, Suffolk County, Mass.
# Found place in cache, serving from redis...
# Livingston County, Mich.
# Found place in cache, serving from redis...
# Benson, Swift County, Minn.
# Found place in cache, serving from redis...
# Minneapolis, Hennepin County, Minn.
# Found place in cache, serving from redis...
# New York, N.Y.
# Found place in cache, serving from redis...
# Tarkio, Atchison County, Mo.
# Found place in cache, serving from redis...
# Billings, Yellowstone County, Mont.
# Found place in cache, serving from redis...
# Hastings, Adams County, Nebr.
# Found place in cache, serving from redis...
# Ridgewood, Bergen County, N.J.
# Found place in cache, serving from redis...
# Brooklyn, Kings County, N.Y.
# Found place in cache, serving from redis...
# Columbus, Franklin County, Ohio
# Found place in cache, serving from redis...
# Tulsa, Tulsa County, Okla.
# Found place in cache, serving from redis...
# Pittsburgh, Allegheny County, Pa.
# Found place in cache, serving from redis...
# McKeesport, Allegheny County, Pa.
# Found place in cache, serving from redis...
# City of Richmond, Va.
# Found place in cache, serving from redis...
# York, York County, Pa.
# Found place in cache, serving from redis...
# Providence, Providence County, R.I.
# Found place in cache, serving from redis...
# Bishopville, Lee County, S.C.
# Found place in cache, serving from redis...
# Charleston, S.C.
# Found place in cache, serving from redis...
# Houston, Harris County, Tex.
# Found place in cache, serving from redis...
# Salt Lake City, Salt Lake County, Utah
# Found place in cache, serving from redis...
# Rowan County, N.C.
# Found place in cache, serving from redis...
# Chesapeake, Chesapeake County, Va.
# Found place in cache, serving from redis...
# Richmond, Henrico County, Va.
# Found place in cache, serving from redis...
# Arlington, Snohomish County, Wash.
# Found place in cache, serving from redis...
# Glendale, Marshall County, W.Va.
# Found place in cache, serving from redis...
# St. Louis, Mo.
# Found place in cache, serving from redis...
# Beach City, Stark County, Ohio
# Found place in cache, serving from redis...
# Milwaukee, Wis.
# Found place in cache, serving from redis...
# Meridian, Sutter County, Calif.
# Found place in cache, serving from redis...
# New Martinsville, Wetzel County, W.Va.
# Found place in cache, serving from redis...
# Okmulgee, Okmulgee County, Okla.
# Found place in cache, serving from redis...
# Selma, Dallas County, Ala.
# Found place in cache, serving from redis...
# Hammond, Lake County, Ind.
# Found place in cache, serving from redis...
# Montgomery, Montgomery County, Ala.
# Found place in cache, serving from redis...
# Fort Monmouth, Monmouth County, N.J.
# Found place in cache, serving from redis...
# Uravan, Montrose County, Colo.
# Found place in cache, serving from redis...
# Tucson, Pima County, Ariz.
# Found place in cache, serving from redis...
# Merced, Merced County, Calif.
# Found place in cache, serving from redis...
# Tulare County, Calif.
# Found place in cache, serving from redis...
# Orange, Orange County, Calif.
# Found place in cache, serving from redis...
# Greeley, Weld County, Colo.
# Found place in cache, serving from redis...
# Lafayette, Boulder County, Colo.
# Found place in cache, serving from redis...
# Albany, Albany County, N.Y.
# Found place in cache, serving from redis...
# Key West, Monroe County, Fla.
# Found place in cache, serving from redis...
# Abington, Montgomery County, Pa.
# Found place in cache, serving from redis...
# Fort Lauderdale, Broward County, Fla.
# Found place in cache, serving from redis...
# Ithaca, Tompkins County, N.Y.
# Found place in cache, serving from redis...
# Augusta, Richmond County, Ga.
# Found place in cache, serving from redis...
# Aynor, Horry County, S.C.
# Found place in cache, serving from redis...
# Hilo, Territory of Hawai'i
# Found place in cache, serving from redis...
# Chicago, Cook County, Ill.
# Found place in cache, serving from redis...
# Jackson, Jackson County, Mich.
# Found place in cache, serving from redis...
# Storm Lake, Buena Vista County, Iowa
# Found place in cache, serving from redis...
# Versailles, Woodford County, Ky.
# Found place in cache, serving from redis...
# Millinocket, Penobscot County, Maine
# Found place in cache, serving from redis...
# Baltimore, Md.
# Found place in cache, serving from redis...
# Karachi, Pakistan
# Found place in cache, serving from redis...
# Detroit, Wayne County, Mich.
# Found place in cache, serving from redis...
# Livonia, Wayne County, Mich.
# Found place in cache, serving from redis...
# Allentown, Lehigh County, Pa.
# Found place in cache, serving from redis...
# Fort Dodge, Webster County, Iowa
# Found place in cache, serving from redis...
# Rumford, Oxford County, Maine
# Found place in cache, serving from redis...
# Englewood, Bergen County, N.J.
# Found place in cache, serving from redis...
# Lamesa, Dawson County, Tex.
# Found place in cache, serving from redis...
# Southampton, Suffolk County, N.Y.
# Found place in cache, serving from redis...
# Wilson, Wilson County, N.C.
# Found place in cache, serving from redis...
# Fayetteville, N.C.
# Found place in cache, serving from redis...
# Dayton, Montgomery County, Ohio
# Found place in cache, serving from redis...
# Niles, Trumbull County, Ohio
# Found place in cache, serving from redis...
# Shreveport, Caddo Parish, La.
# Found place in cache, serving from redis...
# Ellwood City, Lawrence County, Pa.
# Found place in cache, serving from redis...
# Cleveland, Cuyahoga County, Ohio
# Found place in cache, serving from redis...
# Westminster, Oconee County, S.C.
# Found place in cache, serving from redis...
# Near Houghton, S.Dak.
# Found place in cache, serving from redis...
# Pall Mall, Tenn.
# Found place in cache, serving from redis...
# Laurel, Jones County, Miss.
# Found place in cache, serving from redis...
# Stephenville, Erath County, Tex.
# Found place in cache, serving from redis...
# St. Louis, St. Louis County, Mo.
# Found place in cache, serving from redis...
# Rochester, Olmsted County, Minn.
# Found place in cache, serving from redis...
# Houston, Harris County, Tex.
# Found place in cache, serving from redis...
# Kaysville, Davis County, Utah
# Found place in cache, serving from redis...
# Miami, Dade County, Fla.
# Found place in cache, serving from redis...
# Chicago, Cook County, Ill.
# Found place in cache, serving from redis...
# Richmond, Contra Costa County, Calif.
# Found place in cache, serving from redis...
# Chisholm, St. Louis County, Minn.
# Found place in cache, serving from redis...
# Los Angeles, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Pittsburgh, Allegheny County, Pa.
# Found place in cache, serving from redis...
# Topeka, Kans.
# Found place in cache, serving from redis...
# Brooklyn, N.Y.
# Found place in cache, serving from redis...
# Wichita, Sedgwick County, Kans.
# Found place in cache, serving from redis...
# Rutland, Rutland County, Vt.
# Found place in cache, serving from redis...
# Gladwin, Mich.
# Found place in cache, serving from redis...
# Hybart, Ala.
# Found place in cache, serving from redis...
# Arlington, Va.
# Found place in cache, serving from redis...
# Caribou, Aroostook County, Maine
# Found place in cache, serving from redis...
# North Platte, Nebraska
# Found place in cache, serving from redis...
# Pendleton, Oregon
# Found place in cache, serving from redis...
# Bremerton, Wash.
# Found place in cache, serving from redis...
# Boston, Suffolk County, Mass.
# Found place in cache, serving from redis...
# Southgate, Ky.
# Found place in cache, serving from redis...
# Alamosa, Colorado
# Found place in cache, serving from redis...
# Sagua La Grande, Cuba
# Found place in cache, serving from redis...
# Honolulu, Hawaii
# Found place in cache, serving from redis...
# Boston, Suffolk County, Mass.
# Found place in cache, serving from redis...
# Pierre, Hughes County, S. Dak.
# Found place in cache, serving from redis...
# Wichita, Sedgwick County, Kans.
# Found place in cache, serving from redis...
# Honolulu, Hawaii
# Found place in cache, serving from redis...
# El Paso, Tex.
# Found place in cache, serving from redis...
# Paterson, Passaic County, N.J.
# Found place in cache, serving from redis...
# Des Moines, Iowa
# Found place in cache, serving from redis...
# Canton, S.Dak.
# Found place in cache, serving from redis...
# Oakland, Nebr.
# Found place in cache, serving from redis...
# Concord, N.H.
# Found place in cache, serving from redis...
# Tuscumbia, Colbert County, Ala.
# Found place in cache, serving from redis...
# New York City
# Found place in cache, serving from redis...
# Baltimore, Md.
# Found place in cache, serving from redis...
# Helena, Phillips County, Ark.
# Found place in cache, serving from redis...
# St. Louis, Mo.
# Found place in cache, serving from redis...
# Bismarck, Burleigh County, N. Dak.
# Found place in cache, serving from redis...
# San Francisco, Calif.
# Found place in cache, serving from redis...
# Galveston, Tex.
# Found place in cache, serving from redis...
# Salt Lake City, Utah
# Found place in cache, serving from redis...
# Seattle, King County, Wash.
# Found place in cache, serving from redis...
# Janesville, Rock County, Wis.
# Found place in cache, serving from redis...
# Idaho Falls, Bonneville County, Idaho
# Found place in cache, serving from redis...
# Brooklyn, Kings County, N.Y.
# Found place in cache, serving from redis...
# Minneapolis, Minn.
# Found place in cache, serving from redis...
# Pittsburgh, Pa.
# Found place in cache, serving from redis...
# Beckley, Raleigh County, W.Va.
# Found place in cache, serving from redis...
# McCook, Red Willow County, Nebraska
# Found place in cache, serving from redis...
# Indianapolis, Marion County, Ind.
# Found place in cache, serving from redis...
# Taylorville, Christian County, Illinois
# Found place in cache, serving from redis...
# Springfield, Ohio
# Found place in cache, serving from redis...
# East St. Louis, St. Clair County, Ill.
# Found place in cache, serving from redis...
# Park Ridge, Illinois
# Found place in cache, serving from redis...
# Pontotoc, Pontotoc County, Miss.
# Found place in cache, serving from redis...
# St. Louis, Mo.
# Found place in cache, serving from redis...
# Alexandria, Va.
# Found place in cache, serving from redis...
# Honolulu, Hawaii
# Found place in cache, serving from redis...
# Searchlight, Nev.
# Found place in cache, serving from redis...
# Grenada, Grenada County, Miss.
# Found place in cache, serving from redis...
# Atlanta, Fulton County, Ga.
# Found place in cache, serving from redis...
# New Orleans, Orleans Parish, La.
# Found place in cache, serving from redis...
# Shirkieville, Indiana
# Found place in cache, serving from redis...
# Salisbury, Wicomico County, Md.
# Found place in cache, serving from redis...
# Greenville, Greenville County, S.C.
# Found place in cache, serving from redis...
# Cleveland, Ohio
# Found place in cache, serving from redis...
# Warwick, R.I.
# Found place in cache, serving from redis...
# Cody, Park County, Wyo.
# Found place in cache, serving from redis...
# Scranton, Lackawanna County, Pa.
# Found place in cache, serving from redis...
# Albuquerque, Bernalillo County, N.Mex.
# Found place in cache, serving from redis...
# Miami, Dade County, Fla.
# Found place in cache, serving from redis...
# Augusta, Kennebec County, Maine
# Found place in cache, serving from redis...
# Warrenton, Warren County, N.C.
# Found place in cache, serving from redis...
# Indianapolis, Marion County, Ind.
# Found place in cache, serving from redis...
# Garnett, Kans.
# Found place in cache, serving from redis...
# Gallatin, Davies County, Mo.
# Found place in cache, serving from redis...
# North Wilkesboro, Wilkes County, N.C.
# Found place in cache, serving from redis...
# Milwaukee, Milwaukee County, Wis.
# Found place in cache, serving from redis...
# Stamford, Fairfield County, Ct.
# Found place in cache, serving from redis...
# Nashville, Davidson County, Tenn.
# Found place in cache, serving from redis...
# Roseville, Placer County, Calif.
# Found place in cache, serving from redis...
# Charlottesville, Albemarle County, Va.
# Found place in cache, serving from redis...
# Ketchikan, Alaska
# Found place in cache, serving from redis...
# Fayetteville, Arkansas
# Found place in cache, serving from redis...
# Brooklyn, New York
# Found place in cache, serving from redis...
# Salisbury, Rowan County, North Carolina
# Found place in cache, serving from redis...
# Maryville, Tennessee
# Found place in cache, serving from redis...
# Houston, Texas
# Found place in cache, serving from redis...
# Casper, Wyo.
# Found place in cache, serving from redis...
# Detroit, Wayne County, Mich.
# Found place in cache, serving from redis...
# Washington, D.C. and Virginia
# Found place in cache, serving from redis...
# Helena, Lewis and Clark County, Mont.
# Found place in cache, serving from redis...
# Central, Pickens County, S.C.
# Found place in cache, serving from redis...
# Willimantic, Windham County, Conn.
# Found place in cache, serving from redis...
# Indianapolis, Ind.
# Found place in cache, serving from redis...
# New Hartford, Butler County, Iowa
# Found place in cache, serving from redis...
# Cumming, Warren County, Iowa
# Found place in cache, serving from redis...
# Fort Collins, Colo.
# Found place in cache, serving from redis...
# Birmingham, Ala.
# Found place in cache, serving from redis...
# Winchester, Frederick County, Va.
# Found place in cache, serving from redis...
# Providence, R.I.
# Found place in cache, serving from redis...
# Council, Adams County, Idaho
# Found place in cache, serving from redis...
# Dickinson, Stark County, N. Dak.
# Found place in cache, serving from redis...
# Whittier, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Montpelier, Washington County, Vt.
# Found place in cache, serving from redis...
# Nashua, Hillsborough County, N.H.
# Found place in cache, serving from redis...
# Phoenix, Maricopa County, Ariz.
# Found place in cache, serving from redis...
# Tucson, Pima County, Ariz.
# Found place in cache, serving from redis...
# Albuquerque, Bernalillo County, N. Mex.
# Found place in cache, serving from redis...
# Bakersfield, Kern County, Calif.
# Found place in cache, serving from redis...
# Leavenworth, Leavenworth County, Kans.
# Found place in cache, serving from redis...
# Denver, Denver County, Colo.
# Found place in cache, serving from redis...
# West Hartford, Tolland County, Conn.
# Found place in cache, serving from redis...
# White Plains, Westchester County, N.Y.
# Found place in cache, serving from redis...
# Miami, Miami-Dade County, Fla.
# Found place in cache, serving from redis...
# Detroit, Wayne County, Mich.
# Found place in cache, serving from redis...
# Aurora, Kane County, Ill.
# Found place in cache, serving from redis...
# Cleveland, Cuyahoga County, Ohio
# Found place in cache, serving from redis...
# Washington, D.C.
# Found place in cache, serving from redis...
# Fukushima, Japan
# Found place in cache, serving from redis...
# Portsmouth, Scioto County, Ohio
# Found place in cache, serving from redis...
# Hinsdale, DuPage County, Ill.
# Found place in cache, serving from redis...
# Galesburg, Knox County, Ill.
# Found place in cache, serving from redis...
# Queens, Queens County, N.Y.
# Found place in cache, serving from redis...
# Jasper, Dubois County, Ind.
# Found place in cache, serving from redis...
# Grinnell, Poweshiek County, Iowa
# Found place in cache, serving from redis...
# Sioux City, Woodbury County, Iowa
# Found place in cache, serving from redis...
# St. Louis, St. Louis County, Mo.
# Found place in cache, serving from redis...
# Louisville, Jefferson County, Ky.
# Found place in cache, serving from redis...
# Baltimore, Md.
# Found place in cache, serving from redis...
# Chicago, Cook County, Ill.
# Found place in cache, serving from redis...
# West Point, Cuming County, Nebr.
# Found place in cache, serving from redis...
# Detroit, Wayne County, Mich.
# Found place in cache, serving from redis...
# Waterloo, Black Hawk County, Iowa
# Found place in cache, serving from redis...
# Scottsbluff, Scotts Bluff County, Nebr.
# Found place in cache, serving from redis...
# Castro Valley, Alameda County, Calif.
# Found place in cache, serving from redis...
# New York City, New York County, N.Y.
# Found place in cache, serving from redis...
# New York City, New York County, N.Y.
# Found place in cache, serving from redis...
# Brooklyn, Kings County, N.Y.
# Found place in cache, serving from redis...
# Baltimore, Md.
# Found place in cache, serving from redis...
# Albany, Albany County, N.Y.
# Found place in cache, serving from redis...
# Utica, Oneida County, N.Y.
# Found place in cache, serving from redis...
# Swain County, N.C.
# Found place in cache, serving from redis...
# Troy, Miami County, Ohio
# Found place in cache, serving from redis...
# Martins Ferry, Belmont County, Ohio
# Found place in cache, serving from redis...
# Barberton, Summit County, Ohio
# Found place in cache, serving from redis...
# Dover, Tuscarawas County, Ohio
# Found place in cache, serving from redis...
# Warrensburg, Johnson County, Mo.
# Found place in cache, serving from redis...
# Kittanning, Armstrong County, Pa.
# Found place in cache, serving from redis...
# Secane, Delaware County, Pa.
# Found place in cache, serving from redis...
# Philadelphia, Philadelphia County, Pa.
# Found place in cache, serving from redis...
# Cedar Rapids, Linn County, Iowa
# Found place in cache, serving from redis...
# Johnson City, Washington County, Tenn.
# Found place in cache, serving from redis...
# Memphis, Shelby County, Tenn.
# Found place in cache, serving from redis...
# Madison, Dane County, Wis.
# Found place in cache, serving from redis...
# Springfield, Hampden County, Mass.
# Found place in cache, serving from redis...
# Appleton, Outagamie County, Wis.
# Found place in cache, serving from redis...
# Los Angeles, Los Angeles County, Calif.
# Found place in cache, serving from redis...
# Atlanta, Fulton County, Ga.
# Found place in cache, serving from redis...
# Chico, Butte County, Calif.
# Found place in cache, serving from redis...
# Bluffton, Allen County, Ohio
# Found place in cache, serving from redis...
# Washington, D.C.
# Found place in cache, serving from redis...
# Indianapolis, Marion County, Ind.
# Found place in cache, serving from redis...
# Gainesville, Alachua County, Fla.
# Found place in cache, serving from redis...
# New Orleans, Orleans Parish, La.
# Found place in cache, serving from redis...
# New Roads, Pointe Coupee Parish, La
# Found place in cache, serving from redis...
# Booneville, Prentiss County, Miss.
# Found place in cache, serving from redis...
# San Francisco, San Francisco County, Calif.
# Found place in cache, serving from redis...
# Yanceyville, Caswell County, N.C.
# Found place in cache, serving from redis...
# Mangilao, Guam
# Found place in cache, serving from redis...
# Teaneck, Monmouth County, N.J.
# Found place in cache, serving from redis...
# San Juan, P.R.
# Found place in cache, serving from redis...
# Cleveland, Cuyahoga County, Ohio
# Found place in cache, serving from redis...
# Vailoatai Village, American Samoa
# Found place in cache, serving from redis...
# Beaumont, Jefferson County, Tex.
# Found place in cache, serving from redis...
# Piedras Negras, Mexico
# Found place in cache, serving from redis...
# Seymour, Jackson County, Ind.
# Found place in cache, serving from redis...
# Washington, D.C.
# Found place in cache, serving from redis...
# Plymouth, Minn.
# Found place in cache, serving from redis...
# Rolla, Mo.
# Found place in cache, serving from redis...
# Havre, Mont.
# Found place in cache, serving from redis...
# Scranton, Penn.
# Found place in cache, serving from redis...
# Manhattan, N.Y.
# Found place in cache, serving from redis...
# Orangeburg, S.C.
# Found place in cache, serving from redis...
# St. Joseph, Mo.
# Found place in cache, serving from redis...
# Reading, Penn.
# Found place in cache, serving from redis...
# Midland, Dale County, Ala.
# Found place in cache, serving from redis...
# Shreveport, Caddo Parish, La.
# Found place in cache, serving from redis...
# McNary, Apache County, Ariz.
# Found place in cache, serving from redis...
# Bronxville, Westchester County, N.Y.
# Found place in cache, serving from redis...
# Boulder, Boulder County, Colo.
# Found place in cache, serving from redis...
# Cresskill, Bergen County, N. J.
# Found place in cache, serving from redis...
# Fort Leonard Wood, Pulaski County, Mo.
# Found place in cache, serving from redis...
# Lima, Peru
# Found place in cache, serving from redis...
# Bronx, Bronx County, N.Y.
# Found place in cache, serving from redis...
# Washington, D.C.
# Found place in cache, serving from redis...
# Philadelphia, Philadelphia County, Pa.
# Found place in cache, serving from redis...
# Washington, Washington County, D.C.
# Found place in cache, serving from redis...
# Walla Walla, Walla Walla County, Wash.
# Found place in cache, serving from redis...
# Chicago Heights, Cook County, Ill.
# Found place in cache, serving from redis...
# Morris, Stevens County, Minn.
# Found place in cache, serving from redis...
# Holton, Jackson County, Kans.
# Found place in cache, serving from redis...
# Florence, Lauderdale County, Ala.
# Found place in cache, serving from redis...
# Ho Chi Minh City, Vietnam
# Found place in cache, serving from redis...
# Meridian, Lauderdale County, Miss.
# Found place in cache, serving from redis...
# Highland Park, Lake County, Ill.
# Found place in cache, serving from redis...
# Minneapolis, Hennepin County, Minn.
# Found place in cache, serving from redis...
# Lanham, Prince George's County, Md.
# Found place in cache, serving from redis...
# Howell, Livingston County, Mich.
# Found place in cache, serving from redis...
# Pontiac, Oakland County, Mich.
# Found place in cache, serving from redis...
# Bakersfield, Kern County, Calif.
# Found place in cache, serving from redis...
# Jackson, Hinds County, Miss.
# Found place in cache, serving from redis...
# Jefferson City, Cole County, Mo.
# Found place in cache, serving from redis...
# Thomasville, Thomas County, Ga.
# Found place in cache, serving from redis...
# Philadelphia, Philadelphia County, Pa.
# Found place in cache, serving from redis...
# Easton, Northampton County, Pa.
# Found place in cache, serving from redis...
# Fallon, Churchill County, Nev.
# Found place in cache, serving from redis...
# Gracemont, Caddo County, Okla.
# Found place in cache, serving from redis...
# Santa Fe, Santa Fe County, N.Mex.
# Found place in cache, serving from redis...
# Staten Island, Richmond County, N.Y.
# Found place in cache, serving from redis...
# ...
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Omaha, Nebr.
# Found place in cache, serving from redis...
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# (Congress)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# (Congress)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# (Congress)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# (Congress)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Lowell, Mass.
# Found place in cache, serving from redis...
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# (Congress)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# (Congress)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Southmont, Pa. (interment)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# (unsuccessful candidate for reelection to the Senate)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Alexandria, Virginia
# Found place in cache, serving from redis...
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# (United States Senate)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# San Diego, Calif. (Mayor)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Greensboro, N.C.
# Found place in cache, serving from redis...
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Arlington, Va. (interment in Arlington National Cemetery)
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Finished:
#            id start_1  end_1                         location_1  start_2  \
# 0     C001059    1952   1970      Fresno, Fresno County, Calif.     1970
# 1     S001158    1953   1971     Alamosa, Alamosa County, Colo.     1971
# 2     M001155    1967   1985       Fort Myers, Lee County, Fla.     1985
# 3     W000797    1966   1980  Forest Hills, Queens County, N.Y.     1980
# 4     P000591    1954   1972      Lansing, Ingham County, Mich.     1972
# ...       ...     ...    ...                                ...      ...
# 1305  B001319    1982   1996                   Enterprise, Ala.     1996
# 1306  F000479    1969   1983                     Reading, Penn.     1983
# 1307  R000618    1964   1980               Nebraska City, Nebr.     1980
# 1308  S001227    1975   1989                     Bridgeton, Mo.     1989
# 1309  V000137    1984   1999                   Middletown, Ohio     1999
#
#      end_2            location_2  start_3   end_3  \
# 0     1974        Fresno, Calif.   1978.0  1994.0
# 1     1973  (United States Army)   1973.0  1976.0
# 2     1993     Gainesville, Fla.   2000.0  2003.0
# 3     1984       Dix Hills, N.Y.   1984.0  1988.0
# 4     1976       Dearborn, Mich.   1976.0  1979.0
# ...    ...                   ...      ...     ...
# 1305  2000      Enterprise, Ala.   2000.0  2004.0
# 1306  1987           York, Penn.   1987.0  1991.0
# 1307  1982          Omaha, Nebr.   1982.0  1986.0
# 1308  1993        St. Louis, Mo.   1993.0  1997.0
# 1309  2003      Middletown, Ohio   2003.0  2007.0
#
#                                     location_3  ... fips10 error10 fips11  \
# 0                  (California state assembly)  ...   None    None   None
# 1                         (United States Army)  ...   None    None   None
# 2     (Florida state house of representatives)  ...   None    None   None
# 3                            Gainesville, Fla.  ...   None    None   None
# 4                             Ann Arbor, Mich.  ...   None    None   None
# ...                                        ...  ...    ...     ...    ...
# 1305                     University of Alabama  ...   None    None   None
# 1306                            Reading, Penn.  ...   None    None   None
# 1307                             Chicago, Ill.  ...   None    None   None
# 1308                           Kirksville, Mo.  ...   None    None   None
# 1309              (United States Marine Corps)  ...   None    None   None
#
#       error11 fips12 error12 fips13 error13 fips14 error14
# 0        None   None    None   None    None   None    None
# 1        None   None    None   None    None   None    None
# 2        None   None    None   None    None   None    None
# 3        None   None    None   None    None   None    None
# 4        None   None    None   None    None   None    None
# ...       ...    ...     ...    ...     ...    ...     ...
# 1305     None   None    None   None    None   None    None
# 1306     None   None    None   None    None   None    None
# 1307     None   None    None   None    None   None    None
# 1308     None   None    None   None    None   None    None
# 1309     None   None    None   None    None   None    None
#
# [1310 rows x 71 columns]

# %%
df = pd.read_csv('results/gpt4_new_prompt_full_timeline_and_fips.csv')

# %%
# manually replacing fips for locations whose names appear multiple times and cause error "More than one matched place from Google"
dict = {'Los Angeles, Calif.': '6037', 'Honolulu, Hawaii': '15003', 'Philadelphia, Philadelphia County, Pa.': '42101', 'Riverside, Calif.': '6065',  'Williamstown, Mass.': '25003', 'Saugerties, N.Y.': '36111', 'Staten Island, Richmond County, N.Y.': '36085', 'Urbana-Champaign, Ill.': '17019'}

i = 1
while f'location_{i}' in df.columns:
    df.loc[df[f'location_{i}'].isin(dict), f'fips{i}'] = df.loc[df[f'location_{i}'].isin(dict), f'location_{i}'].map(dict) # modifying only pairs with specific locations
    i += 1

# %%
df = df[df.columns.drop(list(df.filter(regex='location')))]
df = df[df.columns.drop(list(df.filter(regex='error')))]

# %%
# reshaping the dataframe
df_long = pd.wide_to_long(df, ['start_', 'end_', 'fips'], i="id", j="number")
df_long = df_long.reset_index()
df_long = df_long[df_long.columns.drop(['number'])]
df_long = df_long.rename(columns={'start_': 'start', 'end_': 'end'})

df_long = df_long.dropna(subset=['fips'])

# %%
# special cases

# modify special case: birth year not explicitly specified
df_long.at[599, 'start'] = 1968

# modify special case: year written as October 17, 2019
df_long.at[8073, 'start'] = 2019

# modify special case: year written as July 27 and 28, 2020
df_long.at[12058, 'start'] = 2020
df_long.at[12058, 'end'] = 2020

# %%
# fixing type of year

for col in ['start', 'end']:
    df_long[col] = df_long[col].replace(['present', 'Present', 'Current'], 2023)
    df_long[col] = df_long[col].replace('?', np.nan)
    df_long[col] = pd.to_numeric(df_long[col], downcast='integer')

df_long['end'] = df_long['end'].fillna(df_long['start'])

# %%
df_long['length'] = df_long['end'].sub(df_long['start'])
df_long['length'] = pd.to_numeric(df_long['length'], downcast='integer')
df_long
# Out:
#             id  start     end     fips  length
# 0      C001059   1952  1970.0   6019.0      18
# 1      S001158   1953  1971.0   8003.0      18
# 2      M001155   1967  1985.0  12071.0      18
# 3      W000797   1966  1980.0  36081.0      14
# 4      P000591   1954  1972.0  26065.0      18
# ...        ...    ...     ...      ...     ...
# 14907  S000064   2007  2020.0  24510.0      13
# 15352  A000373   2022  2022.0  31055.0       0
# 15854  M000627   2007  2023.0  25017.0      16
# 16244  W000154   2009  2021.0  51510.0      12
# 17195  C000556   2015  2015.0  37081.0       0
#
# [5162 rows x 5 columns]

# %%
max_len = max(df_long['length'])
new_columns = [f'year{i}' for i in range(1, max_len+1)]

# Create new columns filled with NaN values
df_long[new_columns] = pd.DataFrame([[pd.NaT] * (max_len)] * len(df_long), index=df_long.index)

for idx, row in df_long.iterrows():
    start_year = row['start']
    length = row['length']
    for i in range(1, length):
        df_long.at[idx, new_columns[i-1]] = start_year + i
    if length != 0:
        df_long.at[idx, new_columns[length-1]] = df_long.loc[idx]['end']

df_long = df_long.rename(columns={'start': 'year0'})
df_long = df_long.drop(['end', 'length'], axis='columns')

# %%
years = [f'year{i}' for i in range(max_len+1)]

# reshape the dataframe into a longer format
df_long2 = df_long.melt(id_vars=['id', 'fips'], value_vars=years, value_name='year')
df_long2 = df_long2.drop(['variable'], axis='columns')
df_long2 = df_long2.dropna(subset=['year'])
df_long2 = df_long2.sort_values(by=['id', 'year'])
df_long2 = df_long2[['id', 'year', 'fips']]
df_long2 = df_long2.drop_duplicates()

# %%
df_long2
# Out:
#             id    year     fips
# 195    A000014    1938  36029.0
# 5357   A000014    1939  36029.0
# 10519  A000014    1940  36029.0
# 15681  A000014    1941  36029.0
# 20843  A000014    1942  36029.0
# ...        ...     ...      ...
# 45850  Z000018    1999   6073.0
# 51012  Z000018    2000   6073.0
# 56174  Z000018    2001   6073.0
# 61336  Z000018    2002   6073.0
# 66498  Z000018  2003.0   6073.0
#
# [41676 rows x 3 columns]

# %%
df_long2.to_csv('results/gpt4_new_prompt_fips.csv', index=False)
